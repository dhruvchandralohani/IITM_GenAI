# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.utils import save_image
import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

batch_size = 128
z_dim = 100
num_classes = 10
img_size = 28
channels = 1
epochs = 50
lr = 0.0002
beta1 = 0.5

os.makedirs("cgan_generated", exist_ok=True)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('.', train=True, download=True, transform=transform),
    batch_size=batch_size,
    shuffle=True
)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 56.6MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.77MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 12.4MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.27MB/s]

# %%
class Generator(nn.Module):
    def __init__(self, z_dim, num_classes, img_shape):
        super().__init__()
        self.label_emb = nn.Embedding(num_classes, num_classes)
        self.img_shape = img_shape
        input_dim = z_dim + num_classes

        self.model = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(True),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(True),

            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(True),

            nn.Linear(1024, int(torch.prod(torch.tensor(img_shape)))),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # Concatenate noise and label embedding
        x = torch.cat([noise, self.label_emb(labels)], dim=1)
        img = self.model(x)
        img = img.view(x.size(0), *self.img_shape)
        return img

# %%
class Discriminator(nn.Module):
    def __init__(self, num_classes, img_shape):
        super().__init__()
        self.label_emb = nn.Embedding(num_classes, num_classes)
        input_dim = int(torch.prod(torch.tensor(img_shape))) + num_classes

        self.model = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, img, labels):
        # Flatten image and concatenate label
        img_flat = img.view(img.size(0), -1)
        x = torch.cat([img_flat, self.label_emb(labels)], dim=1)
        return self.model(x)

# %%
img_shape = (channels, img_size, img_size)

generator = Generator(z_dim, num_classes, img_shape).to(device)
discriminator = Discriminator(num_classes, img_shape).to(device)

criterion = nn.BCELoss()
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(beta1, 0.999))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

# %%
k = 3  # Generator updates per iteration
p = 1  # Discriminator updates per iteration

# %%
for epoch in range(1, epochs + 1):
    for i, (real_imgs, real_labels) in enumerate(train_loader):
        batch_size_curr = real_imgs.size(0)
        real_imgs = real_imgs.to(device)
        real_labels = real_labels.to(device)

        real = torch.ones(batch_size_curr, 1, device=device)
        fake = torch.zeros(batch_size_curr, 1, device=device)

        ### ---- Train Discriminator p times ---- ###
        for _ in range(p):
            z = torch.randn(batch_size_curr, z_dim, device=device)
            fake_labels = torch.randint(0, num_classes, (batch_size_curr,), device=device)

            with torch.no_grad():
                gen_imgs = generator(z, fake_labels)

            # Real images
            real_validity = discriminator(real_imgs, real_labels)
            d_real_loss = criterion(real_validity, real)

            # Fake images
            fake_validity = discriminator(gen_imgs.detach(), fake_labels)
            d_fake_loss = criterion(fake_validity, fake)

            d_loss = d_real_loss + d_fake_loss

            optimizer_D.zero_grad()
            d_loss.backward()
            optimizer_D.step()

        ### ---- Train Generator k times ---- ###
        for _ in range(k):
            z = torch.randn(batch_size_curr, z_dim, device=device)
            gen_labels = torch.randint(0, num_classes, (batch_size_curr,), device=device)
            gen_imgs = generator(z, gen_labels)

            # Try to fool the discriminator
            validity = discriminator(gen_imgs, gen_labels)
            g_loss = criterion(validity, real)  # want D(G(z)) = 1

            optimizer_G.zero_grad()
            g_loss.backward()
            optimizer_G.step()

        # Print progress
        if i % 200 == 0:
            print(f"[Epoch {epoch}/{epochs}] [Batch {i}/{len(train_loader)}] "
                  f"D Loss: {d_loss.item():.4f} | G Loss: {g_loss.item():.4f}")

    # Save example images after each epoch
    generator.eval()
    with torch.no_grad():
        z = torch.randn(10, z_dim, device=device)
        labels = torch.arange(0, 10, dtype=torch.long, device=device)
        samples = generator(z, labels)
        samples = samples * 0.5 + 0.5  # Denormalize
        save_image(samples, f"cgan_generated/epoch_{epoch}.png", nrow=10)
    generator.train()
# Out:
# [Epoch 1/50] [Batch 0/469] D Loss: 1.3981 | G Loss: 0.5717
# [Epoch 1/50] [Batch 200/469] D Loss: 1.3837 | G Loss: 0.6472
# [Epoch 1/50] [Batch 400/469] D Loss: 1.3707 | G Loss: 0.6674
# [Epoch 2/50] [Batch 0/469] D Loss: 1.3861 | G Loss: 0.6555
# [Epoch 2/50] [Batch 200/469] D Loss: 1.3817 | G Loss: 0.6983
# [Epoch 2/50] [Batch 400/469] D Loss: 1.3584 | G Loss: 0.7138
# [Epoch 3/50] [Batch 0/469] D Loss: 1.3716 | G Loss: 0.6829
# [Epoch 3/50] [Batch 200/469] D Loss: 1.4026 | G Loss: 0.6727
# [Epoch 3/50] [Batch 400/469] D Loss: 1.3662 | G Loss: 0.6929
# [Epoch 4/50] [Batch 0/469] D Loss: 1.4064 | G Loss: 0.6960
# [Epoch 4/50] [Batch 200/469] D Loss: 1.3955 | G Loss: 0.7097
# [Epoch 4/50] [Batch 400/469] D Loss: 1.4073 | G Loss: 0.7166
# [Epoch 5/50] [Batch 0/469] D Loss: 1.4045 | G Loss: 0.6947
# [Epoch 5/50] [Batch 200/469] D Loss: 1.3706 | G Loss: 0.7089
# [Epoch 5/50] [Batch 400/469] D Loss: 1.3769 | G Loss: 0.7099
# [Epoch 6/50] [Batch 0/469] D Loss: 1.3949 | G Loss: 0.6984
# [Epoch 6/50] [Batch 200/469] D Loss: 1.4028 | G Loss: 0.7019
# [Epoch 6/50] [Batch 400/469] D Loss: 1.3906 | G Loss: 0.6774
# [Epoch 7/50] [Batch 0/469] D Loss: 1.3909 | G Loss: 0.6839
# [Epoch 7/50] [Batch 200/469] D Loss: 1.3736 | G Loss: 0.6975
# [Epoch 7/50] [Batch 400/469] D Loss: 1.4088 | G Loss: 0.6800
# [Epoch 8/50] [Batch 0/469] D Loss: 1.3947 | G Loss: 0.6937
# [Epoch 8/50] [Batch 200/469] D Loss: 1.3970 | G Loss: 0.7101
# [Epoch 8/50] [Batch 400/469] D Loss: 1.3950 | G Loss: 0.6987
# [Epoch 9/50] [Batch 0/469] D Loss: 1.3725 | G Loss: 0.6858
# [Epoch 9/50] [Batch 200/469] D Loss: 1.3823 | G Loss: 0.7067
# [Epoch 9/50] [Batch 400/469] D Loss: 1.3861 | G Loss: 0.7000
# [Epoch 10/50] [Batch 0/469] D Loss: 1.3799 | G Loss: 0.7006
# [Epoch 10/50] [Batch 200/469] D Loss: 1.4275 | G Loss: 0.6865
# [Epoch 10/50] [Batch 400/469] D Loss: 1.3498 | G Loss: 0.7159
# [Epoch 11/50] [Batch 0/469] D Loss: 1.3731 | G Loss: 0.7263
# [Epoch 11/50] [Batch 200/469] D Loss: 1.3532 | G Loss: 0.7301
# [Epoch 11/50] [Batch 400/469] D Loss: 1.3267 | G Loss: 0.7685
# [Epoch 12/50] [Batch 0/469] D Loss: 1.3498 | G Loss: 0.7626
# [Epoch 12/50] [Batch 200/469] D Loss: 1.3061 | G Loss: 0.8293
# [Epoch 12/50] [Batch 400/469] D Loss: 1.3143 | G Loss: 0.7632
# [Epoch 13/50] [Batch 0/469] D Loss: 1.3005 | G Loss: 0.7852
# [Epoch 13/50] [Batch 200/469] D Loss: 1.2973 | G Loss: 0.7872
# [Epoch 13/50] [Batch 400/469] D Loss: 1.2305 | G Loss: 0.8754
# [Epoch 14/50] [Batch 0/469] D Loss: 1.2886 | G Loss: 0.7772
# [Epoch 14/50] [Batch 200/469] D Loss: 1.2629 | G Loss: 1.0059
# [Epoch 14/50] [Batch 400/469] D Loss: 1.2655 | G Loss: 0.8428
# [Epoch 15/50] [Batch 0/469] D Loss: 1.3180 | G Loss: 1.0405
# [Epoch 15/50] [Batch 200/469] D Loss: 1.3140 | G Loss: 0.9143
# [Epoch 15/50] [Batch 400/469] D Loss: 1.3189 | G Loss: 0.8425
# [Epoch 16/50] [Batch 0/469] D Loss: 1.2374 | G Loss: 1.0586
# [Epoch 16/50] [Batch 200/469] D Loss: 1.2548 | G Loss: 0.8858
# [Epoch 16/50] [Batch 400/469] D Loss: 1.2520 | G Loss: 0.9946
# [Epoch 17/50] [Batch 0/469] D Loss: 1.2155 | G Loss: 1.0685
# [Epoch 17/50] [Batch 200/469] D Loss: 1.2826 | G Loss: 0.8290
# [Epoch 17/50] [Batch 400/469] D Loss: 1.2607 | G Loss: 0.8893
# [Epoch 18/50] [Batch 0/469] D Loss: 1.2826 | G Loss: 0.9757
# [Epoch 18/50] [Batch 200/469] D Loss: 1.2646 | G Loss: 0.9230
# [Epoch 18/50] [Batch 400/469] D Loss: 1.3242 | G Loss: 0.7814
# [Epoch 19/50] [Batch 0/469] D Loss: 1.2466 | G Loss: 1.0278
# [Epoch 19/50] [Batch 200/469] D Loss: 1.2356 | G Loss: 0.9099
# [Epoch 19/50] [Batch 400/469] D Loss: 1.2642 | G Loss: 0.8116
# [Epoch 20/50] [Batch 0/469] D Loss: 1.2383 | G Loss: 0.9354
# [Epoch 20/50] [Batch 200/469] D Loss: 1.2881 | G Loss: 0.9627
# [Epoch 20/50] [Batch 400/469] D Loss: 1.2618 | G Loss: 0.9779
# [Epoch 21/50] [Batch 0/469] D Loss: 1.2878 | G Loss: 0.9018
# [Epoch 21/50] [Batch 200/469] D Loss: 1.2178 | G Loss: 0.9672
# [Epoch 21/50] [Batch 400/469] D Loss: 1.2997 | G Loss: 1.0212
# [Epoch 22/50] [Batch 0/469] D Loss: 1.2518 | G Loss: 1.0139
# [Epoch 22/50] [Batch 200/469] D Loss: 1.2606 | G Loss: 0.9571
# [Epoch 22/50] [Batch 400/469] D Loss: 1.3698 | G Loss: 1.1155
# [Epoch 23/50] [Batch 0/469] D Loss: 1.1239 | G Loss: 0.9063
# [Epoch 23/50] [Batch 200/469] D Loss: 1.2311 | G Loss: 1.0043
# [Epoch 23/50] [Batch 400/469] D Loss: 1.2780 | G Loss: 0.9899
# [Epoch 24/50] [Batch 0/469] D Loss: 1.2637 | G Loss: 0.8138
# [Epoch 24/50] [Batch 200/469] D Loss: 1.3122 | G Loss: 0.9296
# [Epoch 24/50] [Batch 400/469] D Loss: 1.2942 | G Loss: 0.8957
# [Epoch 25/50] [Batch 0/469] D Loss: 1.2689 | G Loss: 0.9297
# [Epoch 25/50] [Batch 200/469] D Loss: 1.2637 | G Loss: 0.7431
# [Epoch 25/50] [Batch 400/469] D Loss: 1.2349 | G Loss: 1.0430
# [Epoch 26/50] [Batch 0/469] D Loss: 1.2595 | G Loss: 1.1169
# [Epoch 26/50] [Batch 200/469] D Loss: 1.2516 | G Loss: 0.9389
# [Epoch 26/50] [Batch 400/469] D Loss: 1.3559 | G Loss: 0.7910
# [Epoch 27/50] [Batch 0/469] D Loss: 1.2355 | G Loss: 0.8261
# [Epoch 27/50] [Batch 200/469] D Loss: 1.2553 | G Loss: 0.9326
# [Epoch 27/50] [Batch 400/469] D Loss: 1.2315 | G Loss: 0.8940
# [Epoch 28/50] [Batch 0/469] D Loss: 1.2505 | G Loss: 0.9864
# [Epoch 28/50] [Batch 200/469] D Loss: 1.2503 | G Loss: 1.0788
# [Epoch 28/50] [Batch 400/469] D Loss: 1.2719 | G Loss: 0.8759
# [Epoch 29/50] [Batch 0/469] D Loss: 1.2233 | G Loss: 1.0947
# [Epoch 29/50] [Batch 200/469] D Loss: 1.2539 | G Loss: 0.9034
# [Epoch 29/50] [Batch 400/469] D Loss: 1.2667 | G Loss: 1.0069
# [Epoch 30/50] [Batch 0/469] D Loss: 1.2613 | G Loss: 0.8633
# [Epoch 30/50] [Batch 200/469] D Loss: 1.2574 | G Loss: 1.1388
# [Epoch 30/50] [Batch 400/469] D Loss: 1.2797 | G Loss: 0.9996
# [Epoch 31/50] [Batch 0/469] D Loss: 1.2755 | G Loss: 1.0446
# [Epoch 31/50] [Batch 200/469] D Loss: 1.3151 | G Loss: 0.9080
# [Epoch 31/50] [Batch 400/469] D Loss: 1.1918 | G Loss: 1.0545
# [Epoch 32/50] [Batch 0/469] D Loss: 1.2704 | G Loss: 1.0031
# [Epoch 32/50] [Batch 200/469] D Loss: 1.1834 | G Loss: 1.0370
# [Epoch 32/50] [Batch 400/469] D Loss: 1.3299 | G Loss: 1.0487
# [Epoch 33/50] [Batch 0/469] D Loss: 1.2563 | G Loss: 0.8851
# [Epoch 33/50] [Batch 200/469] D Loss: 1.2807 | G Loss: 0.9371
# [Epoch 33/50] [Batch 400/469] D Loss: 1.2114 | G Loss: 1.0727
# [Epoch 34/50] [Batch 0/469] D Loss: 1.2990 | G Loss: 1.0574
# [Epoch 34/50] [Batch 200/469] D Loss: 1.2443 | G Loss: 1.0600
# [Epoch 34/50] [Batch 400/469] D Loss: 1.2115 | G Loss: 1.0201
# [Epoch 35/50] [Batch 0/469] D Loss: 1.3224 | G Loss: 0.8180
# [Epoch 35/50] [Batch 200/469] D Loss: 1.2788 | G Loss: 0.9811
# [Epoch 35/50] [Batch 400/469] D Loss: 1.3383 | G Loss: 0.7591
# [Epoch 36/50] [Batch 0/469] D Loss: 1.1981 | G Loss: 1.1305
# [Epoch 36/50] [Batch 200/469] D Loss: 1.3367 | G Loss: 1.2527
# [Epoch 36/50] [Batch 400/469] D Loss: 1.2459 | G Loss: 1.2857
# [Epoch 37/50] [Batch 0/469] D Loss: 1.2452 | G Loss: 0.9953
# [Epoch 37/50] [Batch 200/469] D Loss: 1.1907 | G Loss: 1.0239
# [Epoch 37/50] [Batch 400/469] D Loss: 1.2441 | G Loss: 0.9376
# [Epoch 38/50] [Batch 0/469] D Loss: 1.2708 | G Loss: 0.9708
# [Epoch 38/50] [Batch 200/469] D Loss: 1.2682 | G Loss: 1.0346
# [Epoch 38/50] [Batch 400/469] D Loss: 1.2972 | G Loss: 0.8495
# [Epoch 39/50] [Batch 0/469] D Loss: 1.1782 | G Loss: 0.9738
# [Epoch 39/50] [Batch 200/469] D Loss: 1.2173 | G Loss: 0.9962
# [Epoch 39/50] [Batch 400/469] D Loss: 1.1570 | G Loss: 0.8776
# [Epoch 40/50] [Batch 0/469] D Loss: 1.2013 | G Loss: 0.8567
# [Epoch 40/50] [Batch 200/469] D Loss: 1.2712 | G Loss: 0.7636
# [Epoch 40/50] [Batch 400/469] D Loss: 1.2231 | G Loss: 1.0329
# [Epoch 41/50] [Batch 0/469] D Loss: 1.3158 | G Loss: 0.9804
# [Epoch 41/50] [Batch 200/469] D Loss: 1.2341 | G Loss: 1.0748
# [Epoch 41/50] [Batch 400/469] D Loss: 1.2697 | G Loss: 1.0410
# [Epoch 42/50] [Batch 0/469] D Loss: 1.2657 | G Loss: 0.9649
# [Epoch 42/50] [Batch 200/469] D Loss: 1.2434 | G Loss: 0.9015
# [Epoch 42/50] [Batch 400/469] D Loss: 1.2359 | G Loss: 0.8690
# [Epoch 43/50] [Batch 0/469] D Loss: 1.2468 | G Loss: 0.8513
# [Epoch 43/50] [Batch 200/469] D Loss: 1.2455 | G Loss: 0.9731
# [Epoch 43/50] [Batch 400/469] D Loss: 1.3367 | G Loss: 1.1314
# [Epoch 44/50] [Batch 0/469] D Loss: 1.2347 | G Loss: 1.1011
# [Epoch 44/50] [Batch 200/469] D Loss: 1.3020 | G Loss: 0.9838
# [Epoch 44/50] [Batch 400/469] D Loss: 1.3928 | G Loss: 1.0737
# [Epoch 45/50] [Batch 0/469] D Loss: 1.2074 | G Loss: 0.9158
# [Epoch 45/50] [Batch 200/469] D Loss: 1.2366 | G Loss: 0.9722
# [Epoch 45/50] [Batch 400/469] D Loss: 1.2343 | G Loss: 4.7423
# [Epoch 46/50] [Batch 0/469] D Loss: 1.3295 | G Loss: 0.9163
# [Epoch 46/50] [Batch 200/469] D Loss: 1.2480 | G Loss: 1.0364
# [Epoch 46/50] [Batch 400/469] D Loss: 1.1310 | G Loss: 0.8496
# [Epoch 47/50] [Batch 0/469] D Loss: 1.2143 | G Loss: 0.9872
# [Epoch 47/50] [Batch 200/469] D Loss: 1.2478 | G Loss: 1.0190
# [Epoch 47/50] [Batch 400/469] D Loss: 1.2720 | G Loss: 1.0348
# [Epoch 48/50] [Batch 0/469] D Loss: 1.2966 | G Loss: 1.0483
# [Epoch 48/50] [Batch 200/469] D Loss: 1.2785 | G Loss: 1.0008
# [Epoch 48/50] [Batch 400/469] D Loss: 1.2850 | G Loss: 0.9001
# [Epoch 49/50] [Batch 0/469] D Loss: 1.2886 | G Loss: 0.7125
# [Epoch 49/50] [Batch 200/469] D Loss: 1.2014 | G Loss: 0.8132
# [Epoch 49/50] [Batch 400/469] D Loss: 1.2524 | G Loss: 0.9117
# [Epoch 50/50] [Batch 0/469] D Loss: 1.2547 | G Loss: 1.0425
# [Epoch 50/50] [Batch 200/469] D Loss: 1.2917 | G Loss: 1.1351
# [Epoch 50/50] [Batch 400/469] D Loss: 1.2711 | G Loss: 1.0908

# %%
def generate_digit_images(generator, digit, num_samples=16, save_path=None):
    generator.eval()
    z = torch.randn(num_samples, z_dim).to(device)
    labels = torch.full((num_samples,), digit, dtype=torch.long).to(device)

    with torch.no_grad():
        gen_imgs = generator(z, labels)
        gen_imgs = gen_imgs * 0.5 + 0.5

    if save_path:
        save_image(gen_imgs, save_path, nrow=4)
        print(f"Saved to {save_path}")
    return gen_imgs

# %%
# Generate 16 samples of digit "7"
generate_digit_images(generator, digit=7, num_samples=16, save_path="cgan_generated/seven.png")
# Out:
# Saved to cgan_generated/seven.png
# tensor([[[[2.9802e-08, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 5.9605e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.0100e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 4.0531e-06, 8.0466e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [7.4506e-07, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[2.9802e-08, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 5.9605e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.3379e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 4.2319e-06, 8.6427e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.8348e-07, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[2.9802e-08, 0.0000e+00, 2.9802e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 8.9407e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 2.8908e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 3.8743e-06, 1.0431e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.0133e-06, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         ...,
#
#
#         [[[2.9802e-08, 0.0000e+00, 2.9802e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 5.9605e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.8743e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 3.6657e-06, 1.0729e-06,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [1.0133e-06, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[2.9802e-08, 0.0000e+00, 2.9802e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 5.9605e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.8445e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 3.3081e-06, 9.2387e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.5367e-07, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]],
#
#
#         [[[2.9802e-08, 0.0000e+00, 2.9802e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 8.9407e-08,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 3.2485e-06],
#           ...,
#           [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [0.0000e+00, 3.9041e-06, 9.8348e-07,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00],
#           [9.5367e-07, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00,
#            0.0000e+00, 0.0000e+00]]]])
